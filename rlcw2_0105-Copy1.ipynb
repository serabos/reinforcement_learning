# %%
! pip install torch gym pygame moviepy
import os 
from utils import DQN, ReplayBuffer, greedy_action, epsilon_greedy, update_target, loss

import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
import math
import numpy as np

import gym
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: torch in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (1.13.0)
# Requirement already satisfied: gym in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (0.26.2)
# Requirement already satisfied: pygame in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (2.1.2)
# Requirement already satisfied: moviepy in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (1.0.3)
# Requirement already satisfied: typing-extensions in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (from torch) (4.3.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (from gym) (0.0.8)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (from gym) (4.11.3)
# Requirement already satisfied: numpy>=1.18.0 in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (from gym) (1.21.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (from gym) (2.0.0)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (from moviepy) (2.28.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (from moviepy) (2.19.3)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (from moviepy) (0.4.7)
# Requirement already satisfied: proglog<=1.0.0 in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (from moviepy) (0.1.10)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (from moviepy) (4.64.1)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (from moviepy) (4.4.2)
# Requirement already satisfied: pillow>=8.3.2 in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (from imageio<3.0,>=2.5->moviepy) (9.2.0)
# Requirement already satisfied: zipp>=0.5 in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.8.0->gym) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/serabostan/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy) (3.4)

# %%
NUM_RUNS = 10

eps_max=1
eps_min=0.2
def eps_decay(step):
    EPSILON =eps_min + (eps_max - eps_min) * \
        math.exp(-1. * step / 200)
    return EPSILON

# %%
runs_results = []

env = gym.make('CartPole-v1')

#looping through runs 
for run in range(NUM_RUNS):
    print(f"Starting run {run+1} of {NUM_RUNS}") #e.g.'Starting running 150 of 5000'
    policy_net = DQN([4,160, 2]) #policy network -- 4-D input, 2 hidden layers of size 50, and 2-D output
    target_net = DQN([4,160, 2]) #target network -- 4-D input, 2 hidden layers of size 50, and 2-D output
    update_target(target_net, policy_net) #takes two DQN objects as arguments and updates the parameters of the *first* one, copying the weights and biases from the second
    target_net.eval()

    optimizer = optim.Adam(policy_net.parameters(), lr=0.0001)
    memory = ReplayBuffer(10000) 
    batch_size = 256

    steps_done = 0

    episode_durations = []

    #looping through 1000 number of episodes:
    for i_episode in range(1000): 
        if (i_episode+1) % 50 == 0:
            print("episode ", i_episode+1, "/", 1000)

        observation, info = env.reset() 
        state = torch.tensor(observation).float()

        done = False
        terminated = False
        t = 0
        while not (done or terminated):

            # Select and perform an action
            #Performing epsilon-greedy action
            action = epsilon_greedy(EPSILON, policy_net, state)
            
            observation, reward, done, terminated, info = env.step(action)
            reward = torch.tensor([reward])
            action = torch.tensor([action])
            next_state = torch.tensor(observation).reshape(-1).float()
            #renew the Q-value after each state after deleting the old one
            memory.push([state, action, next_state, reward, torch.tensor([done])])

            # Move to the next state
            state = next_state

            # Perform one step of the optimization (on the policy network)
            if not len(memory.buffer) < batch_size:
                transitions = memory.sample(batch_size)
                state_batch, action_batch, nextstate_batch, reward_batch, dones = (torch.stack(x) for x in zip(*transitions))
                # Compute loss
                mse_loss = loss(policy_net, target_net, state_batch, action_batch, reward_batch, nextstate_batch, dones)
                # Optimize the model
                optimizer.zero_grad()
                mse_loss.backward()
                optimizer.step()
            
            if done or terminated:
                episode_durations.append(t + 1)
            t += 1
        # Update the target network, copying all weights and biases in DQN
        if i_episode % 30 == 0: 
            update_target(target_net, policy_net)
    runs_results.append(episode_durations)
print('Complete')
# Out:
# Starting run 1 of 10
# episode  50 / 1000
# episode  100 / 1000
# episode  150 / 1000
# episode  200 / 1000
# episode  250 / 1000
# episode  300 / 1000
# episode  350 / 1000
# episode  400 / 1000
# episode  450 / 1000
# episode  500 / 1000
# episode  550 / 1000
# episode  600 / 1000
# episode  650 / 1000
# episode  700 / 1000
# episode  750 / 1000
# episode  800 / 1000
# episode  850 / 1000
# episode  900 / 1000
# episode  950 / 1000
# episode  1000 / 1000
# Starting run 2 of 10
# episode  50 / 1000
# episode  100 / 1000
# episode  150 / 1000
# episode  200 / 1000
# episode  250 / 1000
# episode  300 / 1000
# episode  350 / 1000
# episode  400 / 1000
# episode  450 / 1000
# episode  500 / 1000
# episode  550 / 1000
# episode  600 / 1000
# episode  650 / 1000
# episode  700 / 1000
# episode  750 / 1000
# episode  800 / 1000
# episode  850 / 1000
# episode  900 / 1000
# episode  950 / 1000
# episode  1000 / 1000
# Starting run 3 of 10
# episode  50 / 1000
# episode  100 / 1000
# episode  150 / 1000
# episode  200 / 1000
# episode  250 / 1000
# episode  300 / 1000
# episode  350 / 1000
# episode  400 / 1000
# episode  450 / 1000
# episode  500 / 1000
# episode  550 / 1000
# episode  600 / 1000
# episode  650 / 1000
# episode  700 / 1000
# episode  750 / 1000
# episode  800 / 1000
# episode  850 / 1000
# episode  900 / 1000
# episode  950 / 1000
# episode  1000 / 1000
# Starting run 4 of 10
# episode  50 / 1000
# episode  100 / 1000
# episode  150 / 1000
# episode  200 / 1000
# episode  250 / 1000
# episode  300 / 1000
# episode  350 / 1000
# episode  400 / 1000
# episode  450 / 1000
# episode  500 / 1000
# episode  550 / 1000
# episode  600 / 1000
# episode  650 / 1000
# episode  700 / 1000
# episode  750 / 1000
# episode  800 / 1000
# episode  850 / 1000
# episode  900 / 1000
# episode  950 / 1000
# episode  1000 / 1000
# Starting run 5 of 10
# episode  50 / 1000
# episode  100 / 1000
# episode  150 / 1000
# episode  200 / 1000
# episode  250 / 1000
# episode  300 / 1000
# episode  350 / 1000
# episode  400 / 1000
# episode  450 / 1000
# episode  500 / 1000
# episode  550 / 1000
# episode  600 / 1000
# episode  650 / 1000
# episode  700 / 1000
# episode  750 / 1000
# episode  800 / 1000
# episode  850 / 1000
# episode  900 / 1000
# episode  950 / 1000
# episode  1000 / 1000
# Starting run 6 of 10
# episode  50 / 1000
# episode  100 / 1000
# episode  150 / 1000
# episode  200 / 1000
# episode  250 / 1000
# episode  300 / 1000
# episode  350 / 1000
# episode  400 / 1000
# episode  450 / 1000
# episode  500 / 1000
# episode  550 / 1000
# episode  600 / 1000
# episode  650 / 1000
# episode  700 / 1000
# episode  750 / 1000
# episode  800 / 1000
# episode  850 / 1000
# episode  900 / 1000
# episode  950 / 1000
# episode  1000 / 1000
# Starting run 7 of 10
# episode  50 / 1000
# episode  100 / 1000
# episode  150 / 1000
# episode  200 / 1000
# episode  250 / 1000
# episode  300 / 1000
# episode  350 / 1000
# episode  400 / 1000
# episode  450 / 1000
# episode  500 / 1000
# episode  550 / 1000
# episode  600 / 1000
# episode  650 / 1000
# episode  700 / 1000
# episode  750 / 1000
# episode  800 / 1000
# episode  850 / 1000
# episode  900 / 1000
# episode  950 / 1000
# episode  1000 / 1000
# Starting run 8 of 10
# episode  50 / 1000
# episode  100 / 1000
# episode  150 / 1000
# episode  200 / 1000
# episode  250 / 1000
# episode  300 / 1000
# episode  350 / 1000
# episode  400 / 1000
# episode  450 / 1000
# episode  500 / 1000
# episode  550 / 1000
# episode  600 / 1000
# episode  650 / 1000
# episode  700 / 1000
# episode  750 / 1000
# episode  800 / 1000
# episode  850 / 1000
# episode  900 / 1000
# episode  950 / 1000
# episode  1000 / 1000
# Starting run 9 of 10
# episode  50 / 1000
# episode  100 / 1000
# episode  150 / 1000
# episode  200 / 1000
# episode  250 / 1000
# episode  300 / 1000
# episode  350 / 1000
# episode  400 / 1000
# episode  450 / 1000
# episode  500 / 1000
# episode  550 / 1000
# episode  600 / 1000
# episode  650 / 1000
# episode  700 / 1000
# episode  750 / 1000
# episode  800 / 1000
# episode  850 / 1000
# episode  900 / 1000
# episode  950 / 1000
# episode  1000 / 1000
# Starting run 10 of 10
# episode  50 / 1000
# episode  100 / 1000
# episode  150 / 1000
# episode  200 / 1000
# episode  250 / 1000
# episode  300 / 1000
# episode  350 / 1000
# episode  400 / 1000
# episode  450 / 1000
# episode  500 / 1000
# episode  550 / 1000
# episode  600 / 1000
# episode  650 / 1000
# episode  700 / 1000
# episode  750 / 1000
# episode  800 / 1000
# episode  850 / 1000
# episode  900 / 1000
# episode  950 / 1000
# episode  1000 / 1000
# Complete

# %%
# Plotting the learning curve
# Placeholder plot, you are free to modify it
 
results = torch.tensor(runs_results)
means = results.float().mean(0)
stds = results.float().std(0)

plt.plot(torch.arange(1000), means)
plt.title('Learning curve with a learning rate of 0.0001')
plt.ylabel("Return")
plt.xlabel("Episode")
plt.fill_between(torch.arange(1000), means, means+stds, alpha=0.3, color='b')
plt.fill_between(torch.arange(1000), means, means-stds, alpha=0.3, color='b')

plt.savefig('test.png', bbox_inches='tight')

plt.show()

# %%
# Visualising the greedy Q-values for a stationary cart in the middle of the track
# 2D plot showing policy as a function of pole angle and angular velocity (omega)

# This plots the policy and Q values according to the network currently
# stored in the variable "policy_net"

# All visualisations provided here are placeholders and you can modify these plots

# Make sure to include appropriate labels and/or legends when presenting your plot

#policy_net = DQN([4,160, 2])   # randomly initialised, replace with your trained DQN
q = True    # whether q values or greedy policy is visualised

angle_range = .2095 # you may modify this range
omega_range = 2.5  # you may modify this range

angle_samples = 100
omega_samples = 100
angles = torch.linspace(angle_range, -angle_range, angle_samples)
omegas = torch.linspace(-omega_range, omega_range, omega_samples)

greedy_q_array = torch.zeros((angle_samples, omega_samples))
policy_array = torch.zeros((angle_samples, omega_samples))
for i, angle in enumerate(angles):
    for j, omega in enumerate(omegas):
        state = torch.tensor([0., 1., angle, omega])
        with torch.no_grad():
            q_vals = policy_net(state)
            greedy_action = q_vals.argmax()
            greedy_q_array[i, j] = q_vals[greedy_action]
            policy_array[i, j] = greedy_action
if q:
    plt.contourf(angles, omegas, greedy_q_array.T, cmap='cividis', levels=100)
else:
    plt.contourf(angles, omegas, policy_array.T, cmap='cividis')
    
plt.xlabel("Angle")
plt.ylabel("Angular Velocity")

plt.title('Greedy Policy when Cart Velocity is 0')
plt.show()
